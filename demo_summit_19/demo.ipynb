# %%
# This is only to have more logging information
import logging
from importlib import reload
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')
import pandas as pd

# %%
import numpy as np
import pandas as pd
import pandas_profiling

# %%
pdf = pd.read_csv("fire-calls-small.csv", delimiter=":", header=0)
print(pdf.shape)
pdf = pdf[pdf.columns]
# Out:
# (99, 34)

# %%
profile = pandas_profiling.ProfileReport(pdf)
profile
# Out:
# freq_table:freqtable: index
# False    55
# True     44
# Name: ALS Unit, dtype: int64
# freq_table:freqtable: index
# 800 Block of BUSH ST                2
# 900 Block of MARKET ST              2
# 900 Block of FOLSOM ST              2
# 1100 Block of MARKET ST             2
# 400 Block of CALIFORNIA ST          1
# 200 Block of JONES ST               1
# 300 Block of WEST PORTAL AVE        1
# ORIZABA AV/THRIFT ST                1
# 100 Block of SADOWA ST              1
# 2200 Block of BROADWAY              1
# KEITH ST/QUESADA AV                 1
# 1700 Block of SUNNYDALE AVE         1
# 2100 Block of 29TH AVE              1
# DIVISADERO ST/MCALLISTER ST         1
# 500 Block of 38TH AVE               1
# 19TH AV/IRVING ST                   1
# 800 Block of HAIGHT ST              1
# 100 Block of PARKER AVE             1
# COLUMBUS AV/GREEN ST                1
# 2200 Block of MARKET ST             1
# 1100 Block of GENEVA AVE            1
# 400 Block of VALENCIA ST            1
# MARKET ST/POWELL ST                 1
# 0 Block of 4TH ST                   1
# CALIFORNIA ST/GRANT AV              1
# 300 Block of 7TH ST                 1
# 1200 Block of LA SALLE AVE          1
# ELLIS ST/MARKET ST                  1
# 1800 Block of IRVING ST             1
# 500 Block of MARKET ST              1
#                                    ..
# 1100 Block of HOWARD ST             1
# 800 Block of 3RD ST                 1
# ALPHA ST/LELAND AV                  1
# 0 Block of HARDING RD               1
# 500 Block of CALIFORNIA ST          1
# 2200 Block of JERROLD AVE           1
# 600 Block of HARRISON ST            1
# 8TH ST/MISSION ST                   1
# 300 Block of CONNECTICUT ST         1
# 200 Block of KEARNY ST              1
# 2700 Block of MCALLISTER ST         1
# 200 Block of STRATFORD DR           1
# 3RD ST/JESSIE ST                    1
# 3700 Block of 21ST ST               1
# 1100 Block of SOUTH VAN NESS AVE    1
# 700 Block of KIRKWOOD AVE           1
# 1300 Block of STOCKTON ST           1
# 900 Block of INDIANA ST             1
# 0 Block of APPLETON AVE             1
# 400 Block of BRYANT ST              1
# 0 Block of BALDWIN CT               1
# 17TH ST/VALENCIA ST                 1
# 300 Block of ARBALLO DR             1
# 2500 Block of OCEAN AVE             1
# 2300 Block of FOLSOM ST             1
# 3000 Block of MISSION ST            1
# 700 Block of PARNASSUS AVE          1
# CENTRAL AV/HAIGHT ST                1
# 200 Block of POTRERO AVE            1
# 17TH ST/ROOSEVELT WY                1
# Name: Address, Length: 95, dtype: int64
# freq_table:freqtable: index
# B03    23
# B05    13
# B08    11
# B09    10
# B01    10
# B10     9
# B02     8
# B06     7
# B04     5
# B07     3
# Name: Battalion, dtype: int64
# freq_table:freqtable: index
# 04/14/2000    22
# 04/16/2000    19
# 04/17/2000    18
# 04/15/2000    14
# 04/13/2000    14
# 04/18/2000     9
# 04/12/2000     3
# Name: Call Date, dtype: int64
# freq_table:freqtable: index
# Other                         97
# No Merit                       1
# Patient Declined Transport     1
# Name: Call Final Disposition, dtype: int64
# freq_table:freqtable: index
# Medical Incident                 70
# Alarms                           11
# Structure Fire                    9
# Citizen Assist / Service Call     5
# Other                             4
# Name: Call Type, dtype: int64
# freq_table:freqtable: index
# SF    98
# TI     1
# Name: City, dtype: int64
# freq_table:freqtable: index
# 3    76
# 2    23
# Name: Final Priority, dtype: int64
# freq_table:freqtable: index
# 3       15
# 1       13
# 5       13
# 2       11
# 10      10
# 9       10
# 8       10
# 6        7
# 4        5
# 7        4
# None     1
# Name: Fire Prevention District, dtype: int64
# freq_table:freqtable: index
# 04/13/2000 02:33:33 AM    1
# 04/17/2000 11:07:52 PM    1
# 04/14/2000 12:52:28 PM    1
# 04/16/2000 01:10:53 AM    1
# 04/14/2000 01:11:08 PM    1
# 04/16/2000 03:07:19 PM    1
# 04/16/2000 01:53:38 PM    1
# 04/13/2000 08:28:37 AM    1
# 04/17/2000 09:37:03 AM    1
# 04/18/2000 08:55:38 AM    1
# 04/13/2000 09:34:18 PM    1
# 04/18/2000 07:51:05 AM    1
# 04/17/2000 02:34:56 PM    1
# 04/17/2000 08:17:08 PM    1
# 04/17/2000 09:25:42 AM    1
# 04/14/2000 07:26:00 PM    1
# 04/12/2000 11:22:17 PM    1
# 04/14/2000 06:17:13 PM    1
# 04/16/2000 05:12:57 PM    1
# 04/18/2000 11:13:41 AM    1
# 04/16/2000 05:23:17 PM    1
# 04/16/2000 04:20:23 PM    1
# 04/14/2000 12:54:34 PM    1
# 04/15/2000 01:56:25 PM    1
# 04/17/2000 10:54:07 PM    1
# 04/15/2000 02:09:44 PM    1
# 04/14/2000 02:21:42 AM    1
# 04/14/2000 07:57:25 PM    1
# Name: Hospital DtTm, dtype: int64
# freq_table:freqtable: index
# (37.7122553983208, -122.417104410317)    2
# (37.7796660426062, -122.41371122073)     2
# (37.7851251468157, -122.404965960872)    1
# (37.7174212080814, -122.46263331106)     1
# (37.7454233547174, -122.401209234394)    1
# (37.7898998860136, -122.411265644258)    1
# (37.7943158335814, -122.434085882991)    1
# (37.7386734727303, -122.423682182176)    1
# (37.7485954399415, -122.418024677603)    1
# (37.7226584556741, -122.412468270392)    1
# (37.7834598143872, -122.412571882023)    1
# (37.7434621783241, -122.487610566605)    1
# (37.778489948235, -122.498662035969)     1
# (37.8225682263653, -122.371537518925)    1
# (37.7704263698292, -122.443649086138)    1
# (37.7930615497479, -122.401553026249)    1
# (37.7314853147957, -122.472647880057)    1
# (37.7291935618432, -122.374002352858)    1
# (37.7828208961152, -122.454351033841)    1
# (37.7933796204253, -122.398184018556)    1
# (37.7765647940442, -122.407516832678)    1
# (37.7123626229046, -122.457530975594)    1
# (37.7806601472353, -122.431293406245)    1
# (37.7625475763079, -122.461392586573)    1
# (37.7897914509307, -122.411243472923)    1
# (37.7798358670927, -122.414296503337)    1
# (37.7927320655845, -122.40413464889)     1
# (37.7649516607095, -122.431937558766)    1
# T15     1
# E07     1
# T16     1
# E21     1
# B04     1
# E18     1
# T14     1
# Name: Unit ID, dtype: int64
# freq_table:freqtable: index
# ENGINE          40
# MEDIC           30
# AIRPORT         11
# TRUCK            6
# RESCUE SQUAD     5
# CHIEF            4
# PRIVATE          3
# Name: Unit Type, dtype: int64
# freq_table:freqtable: index
# 04/16/2000    20
# 04/14/2000    18
# 04/17/2000    18
# 04/13/2000    17
# 04/15/2000    14
# 04/12/2000     6
# 04/18/2000     6
# Name: Watch Date, dtype: int64
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>35 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>99 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>7.5% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>26.5 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>273.8 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>18 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Address"><code>Address</code></a> has a high cardinality: 95 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Call Number"><code>Call Number</code></a> is highly correlated with <a href="#pp_var_index"><code>index</code></a> (ρ = 0.98396) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Call Type Group"><code>Call Type Group</code></a> has 99 / 100.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Call Type Group"><code>Call Type Group</code></a> has constant value  <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Hospital DtTm"><code>Hospital DtTm</code></a> has 71 / 71.7% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Incident Number"><code>Incident Number</code></a> is highly correlated with <a href="#pp_var_Call Number"><code>Call Number</code></a> (ρ = 0.98429) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_Location"><code>Location</code></a> has a high cardinality: 97 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Number of Alarms"><code>Numb

# %%
import databricks.koala
import pyspark

sc = pyspark.SparkContext.getOrCreate()
spark = pyspark.sql.SparkSession(sc)
# Out:
# 11:21:23 INFO:Patching spark automatically. You can disable it by setting SPARK_PANDAS_AUTOPATCH=false in your environment

# %%
df = spark.read_csv("fire-calls-small.csv", delimiter=":", header=0)
df = df.select(list(df.columns[10:30])) # TODO
df = df.cache()

# %%
profile = pandas_profiling.ProfileReport(df)
profile
# Out:
# freq_table:freqtable: Column<b'ALS Unit'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d76f42a334c6> in <module>
# ----> 1 profile = pandas_profiling.ProfileReport(df)
#       2 profile
#
# ~/work/pandas-profiling/pandas_profiling/__init__.py in __init__(self, df, **kwargs)
#      67
#      68         self.html = to_html(sample,
# ---> 69                             description_set)
#      70
#      71         self.description_set = description_set
#
# ~/work/pandas-profiling/pandas_profiling/report.py in to_html(sample, stats_object)
#     156                                                            templates.template('mini_freq_table_row'),
#     157                                                            3,
# --> 158                                                            templates.mini_freq_table_nb_col[row['type']])
#     159
#     160             if row['distinct_count'] > 50:
#
# ~/work/pandas-profiling/pandas_profiling/report.py in freq_table(freqtable, n, table_template, row_template, max_number_to_print, nb_col)
#     100         # TODO: Correctly sort missing and other
#     101
# --> 102         for label, freq in six.iteritems(freqtable.iloc[0:max_number_to_print]):
#     103             freq_rows_html += _format_row(freq, label, max_freq, row_template, n)
#     104
#
# ~/work/spark-pandas/databricks/koala/series.py in __getattr__(self, item)
#     291         if item.startswith("__") or item.startswith("_pandas_") or item.startswith("_spark_"):
#     292             raise AttributeError(item)
# --> 293         return anchor_wrap(self, self.getField(item))
#     294
#     295     def __invert__(self):
#
# ~/work/spark-pandas/databricks/koala/series.py in getField(self, name)
#      63             if name not in fnames:
#      64                 raise AttributeError(
# ---> 65                     "Field {} not found, possible values are {}".format(name, ", ".join(fnames)))
#      66             return anchor_wrap(self, self._spark_getField(name))
#      67
#
# AttributeError: Field iloc not found, possible values are index, ALS Unit

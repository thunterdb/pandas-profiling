# %%
import numpy as np
import pandas as pd
import pandas_profiling

pdf=pd.DataFrame({"x": [-1.0, 10.0, np.nan], "y": ['a', 'b', 'c']}
)

# %%
import pyspark
import databricks.koala
import pyspark

sc = pyspark.SparkContext.getOrCreate()
spark = pyspark.sql.SparkSession(sc)

# %%
df = spark.from_pandas(pdf)

# %%
df
# Out:
# DataFrame[__index_level_0__: bigint, x: double, y: string]

# %%
pdf.dtypes
# Out:
# x    float64
# y     object
# dtype: object

# %%
df.dtypes
# Out:
# [('__index_level_0__', 'bigint'), ('x', 'double'), ('y', 'string')]

# %%
list(pdf.dtypes)
# Out:
# [dtype('float64'), dtype('O')]

# %%
df.x
# Out:
# 0    -1.0
# 1    10.0
# 2     NaN
# Name: x, dtype: float64

# %%
pdf.count()
# Out:
# x    2
# y    3
# dtype: int64

# %%
df.count()
# Out:
# 3

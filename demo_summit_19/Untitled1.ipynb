# %%
# This is only to have more logging information
import logging
from importlib import reload
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')
import pandas as pd
import numpy as np


import pyspark
import databricks.koala
import pyspark

sc = pyspark.SparkContext.getOrCreate()
spark = pyspark.sql.SparkSession(sc)
# Out:
# 05:00:27 INFO:Patching spark automatically. You can disable it by setting SPARK_PANDAS_AUTOPATCH=false in your environment

# %%
from databricks.koala.structures import anchor_wrap

# %%
pdf=pd.DataFrame({"x": [-1.0, 10.0, None], "y": ['a', 'b', 'c']})

# %%
df = spark.from_pandas(pdf)

# %%
df.show()
# Out:
# +-----------------+----+---+
# |__index_level_0__|   x|  y|
# +-----------------+----+---+
# |                0|-1.0|  a|
# |                1|10.0|  b|
# |                2| NaN|  c|
# +-----------------+----+---+

# %%
pdf.x.isna().value_counts()
# Out:
# False    2
# True     1
# Name: x, dtype: int64

# %%
df.x.isna().value_counts()
# Out:
# False    2
# True     1
# Name: ((x IS NULL) OR isnan(x)), dtype: int64

# %%
pdf.x.value_counts(dropna=False)
# Out:
#  NaN     1
#  10.0    1
# -1.0     1
# Name: x, dtype: int64

# %%
df.x.value_counts(dropna=False)
# Out:
# -1.0     1
#  10.0    1
#  NaN     1
# Name: x, dtype: int64

# %%
pdf.x.isna().value_counts(dropna=False)
# Out:
# False    2
# True     1
# Name: x, dtype: int64

# %%
df.x.isna().value_counts(dropna=False)
# Out:
# False    2
# True     1
# Name: ((x IS NULL) OR isnan(x)), dtype: int64

# %%
f.dataType

# %%
c = df.x.isnull()
df.x._spark_isNull()
anchor_wrap(c, c._spark_alias("x"))
z = anchor_wrap(c, df.x._spark_isNull()._spark_alias("y")).to_dataframe()
z.columns

# %%
z.show()

# %%
z.dtypes

# %%
z._metadata.column_fields
